# %% [markdown]
# <a href="https://colab.research.google.com/github/Hearsch-Jariwala/iWaste-Sorter/blob/main/Waste_Classification_with_Pytorch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # AI Waste Sorting using transfer learning with Pytorch

# %%
# mount google drive
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %% [markdown]
# ### Import packages

# %%
import torch
import numpy as np
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt

import torch
from torch import nn
from torch import optim
import torch.nn.functional as F
from torchvision import datasets, transforms, models
import random,os,glob
from torch.utils.data import random_split
import torchvision
from torchvision.datasets import ImageFolder
import torchvision.transforms as transforms


# check if CUDA is available
train_on_gpu = torch.cuda.is_available()

if not train_on_gpu:
    print('CUDA is not available.  Training on CPU ...')
else:
    print('CUDA is available!  Training on GPU ...')
# Out:
# CUDA is available!  Training on GPU ...

# %% [markdown]
# ## Loading the dataset

# %%
data_dir  = "/gdrive/MyDrive/Dataset"

# %%
img_list = glob.glob(os.path.join(data_dir, '*/*.jpg'))

# %%
len(img_list)
# Out:
# list

# %%
classes = os.listdir(data_dir)
print(classes)
# Out:
# ['metal', 'plastic', 'cardboard', 'paper', 'trash', 'glass']

# %% [markdown]
# ## Image transformation

# %% [markdown]
# Image Resize to 300*300, normalized and converted into tensor

# %%
transformations = transforms.Compose([transforms.Resize((300, 300)), transforms.ToTensor(),transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),])


dataset = ImageFolder(data_dir,transform=transformations)

# %% [markdown]
# create a helper function to see the image and its corresponding label:

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

def show_sample(img, label):
    print("Label:", dataset.classes[label], "(Class No: "+ str(label) + ")")
    plt.imshow(img.permute(1, 2, 0))

# %%
img, label = dataset[2000]
show_sample(img, label)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Label: plastic (Class No: 4)

# %% [markdown]
# Splitting Data:

# %%
random_seed = 42
torch.manual_seed(random_seed)

# %% [markdown]
# We'll split the dataset into training, validation and test sets:

# %%
train_ds, val_ds, test_ds = random_split(dataset, [1593, 176, 758])
len(train_ds), len(val_ds), len(test_ds)
# Out:
# (1593, 176, 758)

# %% [markdown]
# Define batch size to 16

# %%
from torch.utils.data.dataloader import DataLoader
batch_size = 16

# %% [markdown]
# Now, we'll create training and validation dataloaders using DataLoader.

# %%
train_dl = DataLoader(train_ds, batch_size, shuffle = True, num_workers = 4, pin_memory = True)
val_dl = DataLoader(val_ds, batch_size*2, num_workers = 4, pin_memory = True)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %% [markdown]
# This is a helper function to visualize batches:

# %%
def imshow(img):
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()


# get some random training images
dataiter = iter(train_dl)
images, labels = dataiter.next()

# show images
imshow(torchvision.utils.make_grid(images))
# print labels
print(' '.join('%5s' % classes[labels[j]] for j in range(4)))
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# trash paper paper trash

# %%
from torchvision.utils import make_grid

def show_batch(dl):
    for images, labels in dl:
        fig, ax = plt.subplots(figsize=(12, 6))
        ax.set_xticks([])
        ax.set_yticks([])
        ax.imshow(make_grid(images, nrow = 16).permute(1, 2, 0))
        break

# %%
show_batch(train_dl)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ## Model 1

# %% [markdown]
# First, define own neural network model with pytorch

# %%
def accuracy(outputs, labels):
    _, preds = torch.max(outputs, dim=1)
    return torch.tensor(torch.sum(preds == labels).item() / len(preds))

class ImageClassificationBase(nn.Module):
    def training_step(self, batch):
        images, labels = batch 
        out = self(images)                  # Generate predictions
        loss = F.cross_entropy(out, labels) # Calculate loss
        return loss
    
    def validation_step(self, batch):
        images, labels = batch 
        out = self(images)                    # Generate predictions
        loss = F.cross_entropy(out, labels)   # Calculate loss
        acc = accuracy(out, labels)           # Calculate accuracy
        return {'val_loss': loss.detach(), 'val_acc': acc}
        
    def validation_epoch_end(self, outputs):
        batch_losses = [x['val_loss'] for x in outputs]
        epoch_loss = torch.stack(batch_losses).mean()   # Combine losses
        batch_accs = [x['val_acc'] for x in outputs]
        epoch_acc = torch.stack(batch_accs).mean()      # Combine accuracies
        return {'val_loss': epoch_loss.item(), 'val_acc': epoch_acc.item()}
    
    def epoch_end(self, epoch, result):
        print("Epoch {}: train_loss: {:.4f}, val_loss: {:.4f}, val_acc: {:.4f}".format(
            epoch+1, result['train_loss'], result['val_loss'], result['val_acc']))

# %% [markdown]
# Followed pytorch beginner tutorial to define own cnn network : https://pytorch.org/tutorials/beginner/blitz/cifar10_tutorial.html

# %%
import torch.nn as nn
import torch.nn.functional as F

class Net(ImageClassificationBase):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(3, 6, 5)
        self.pool = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(6, 16, 5)
        self.pool = nn.MaxPool2d(2,2)
        #self.fc1 = nn.Linear(16 * 5 * 5, 120) 
        self.fc1 = nn.Linear(16 * 72 * 72, 120)
        self.fc2 = nn.Linear(120, 84)
        self.fc3 = nn.Linear(84, 6)

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        #x = x.view(-1, 16 * 5 * 5)
        x = x.view(-1, 16 * 72 * 72)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x


model = Net()

# %%
def get_default_device():
    
    """Pick GPU if available, else CPU"""
    if torch.cuda.is_available():
        return torch.device('cuda')
    else:
        return torch.device('cpu')
    
def to_device(data, device):
    """Move tensor(s) to chosen device"""
    if isinstance(data, (list,tuple)):
        return [to_device(x, device) for x in data]
    return data.to(device, non_blocking=True)

class DeviceDataLoader():
    """Wrap a dataloader to move data to a device"""
    def __init__(self, dl, device):
        self.dl = dl
        self.device = device
        
    def __iter__(self):
        """Yield a batch of data after moving it to device"""
        for b in self.dl: 
            yield to_device(b, self.device)

    def __len__(self):
        """Number of batches"""
        return len(self.dl)

# %%
device = get_default_device()
device
# Out:
# device(type='cuda')

# %%
train_dl = DeviceDataLoader(train_dl, device)
val_dl = DeviceDataLoader(val_dl, device)

# %%
to_device(model, device)
# Out:
# Net(
#   (conv1): Conv2d(3, 6, kernel_size=(5, 5), stride=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv2d(6, 16, kernel_size=(5, 5), stride=(1, 1))
#   (fc1): Linear(in_features=82944, out_features=120, bias=True)
#   (fc2): Linear(in_features=120, out_features=84, bias=True)
#   (fc3): Linear(in_features=84, out_features=6, bias=True)
# )

# %% [markdown]
# ### Training the Model:

# %% [markdown]
# fitting the model

# %%
 
@torch.no_grad()
def evaluate(model, val_loader):
    model.eval()
    outputs = [model.validation_step(batch) for batch in val_loader]
    return model.validation_epoch_end(outputs)

def fit(epochs, lr, model, train_loader, val_loader, opt_func=torch.optim.SGD):
    history = []
    optimizer = opt_func(model.parameters(), lr)
    for epoch in range(epochs):
        # Training Phase 
        model.train()
        train_losses = []
        for batch in train_loader:
            loss = model.training_step(batch)
            train_losses.append(loss)
            loss.backward()
            optimizer.step()
            optimizer.zero_grad()
        # Validation phase
        result = evaluate(model, val_loader)
        result['train_loss'] = torch.stack(train_losses).mean().item()
        model.epoch_end(epoch, result)
        history.append(result)
    return history

# %%
evaluate(model, val_dl)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# {'val_acc': 0.1770833283662796, 'val_loss': 1.7972803115844727}

# %% [markdown]
# Train

# %%
num_epochs = 100
opt_func = torch.optim.Adam
lr = 5.5e-5

history = fit(num_epochs, lr, model, train_dl, val_dl, opt_func)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Epoch 1: train_loss: 1.6411, val_loss: 1.6133, val_acc: 0.2917
# Epoch 2: train_loss: 1.4446, val_loss: 1.4311, val_acc: 0.4844
# Epoch 3: train_loss: 1.2536, val_loss: 1.4022, val_acc: 0.4635
# Epoch 4: train_loss: 1.1304, val_loss: 1.2840, val_acc: 0.5365
# Epoch 5: train_loss: 1.0467, val_loss: 1.2556, val_acc: 0.5469
# Epoch 6: train_loss: 0.9896, val_loss: 1.2475, val_acc: 0.5469
# Epoch 7: train_loss: 0.9134, val_loss: 1.3209, val_acc: 0.4896
# Epoch 8: train_loss: 0.8335, val_loss: 1.2377, val_acc: 0.5625
# Epoch 9: train_loss: 0.7780, val_loss: 1.2402, val_acc: 0.5260
# Epoch 10: train_loss: 0.7136, val_loss: 1.3273, val_acc: 0.5573
# Epoch 11: train_loss: 0.6619, val_loss: 1.2200, val_acc: 0.5781
# Epoch 12: train_loss: 0.5944, val_loss: 1.2656, val_acc: 0.5625
# Epoch 13: train_loss: 0.5571, val_loss: 1.2732, val_acc: 0.5573
# Epoch 14: train_loss: 0.4900, val_loss: 1.4675, val_acc: 0.4896
# Epoch 15: train_loss: 0.4617, val_loss: 1.3125, val_acc: 0.5521
# Epoch 16: train_loss: 0.4208, val_loss: 1.3315, val_acc: 0.5625
# Epoch 17: train_loss: 0.3599, val_loss: 1.4431, val_acc: 0.5260
# Epoch 18: train_loss: 0.3234, val_loss: 1.5336, val_acc: 0.5365
# Epoch 19: train_loss: 0.3032, val_loss: 1.6201, val_acc: 0.5052
# Epoch 20: train_loss: 0.2560, val_loss: 1.5925, val_acc: 0.5573
# Epoch 21: train_loss: 0.2355, val_loss: 1.5512, val_acc: 0.5156
# Epoch 22: train_loss: 0.1989, val_loss: 1.5945, val_acc: 0.5312
# Epoch 23: train_loss: 0.1938, val_loss: 1.7470, val_acc: 0.5208
# Epoch 24: train_loss: 0.1749, val_loss: 1.9417, val_acc: 0.5052
# Epoch 25: train_loss: 0.1517, val_loss: 1.8617, val_acc: 0.5156
# Epoch 26: train_loss: 0.1299, val_loss: 2.0141, val_acc: 0.5000
# Epoch 27: train_loss: 0.1148, val_loss: 1.9277, val_acc: 0.5260
# Epoch 28: train_loss: 0.1107, val_loss: 1.9337, val_acc: 0.5156
# Epoch 29: train_loss: 0.1041, val_loss: 2.2012, val_acc: 0.5260
# Epoch 30: train_loss: 0.0954, val_loss: 2.1379, val_acc: 0.4844
# Epoch 31: train_loss: 0.0821, val_loss: 2.1365, val_acc: 0.4948
# Epoch 32: train_loss: 0.0803, val_loss: 2.1129, val_acc: 0.5208
# Epoch 33: train_loss: 0.0891, val_loss: 2.2556, val_acc: 0.4844
# Epoch 34: train_loss: 0.1092, val_loss: 2.5710, val_acc: 0.5000
# Epoch 35: train_loss: 0.0904, val_loss: 2.5005, val_acc: 0.4948
# Epoch 36: train_loss: 0.0644, val_loss: 2.2628, val_acc: 0.5104
# Epoch 37: train_loss: 0.0552, val_loss: 2.2309, val_acc: 0.5156
# Epoch 38: train_loss: 0.0508, val_loss: 2.4151, val_acc: 0.4896
# Epoch 39: train_loss: 0.0471, val_loss: 2.3602, val_acc: 0.5104
# Epoch 40: train_loss: 0.0426, val_loss: 2.4746, val_acc: 0.5156
# Epoch 41: train_loss: 0.0428, val_loss: 2.5547, val_acc: 0.5000
# Epoch 42: train_loss: 0.0348, val_loss: 2.5105, val_acc: 0.5156
# Epoch 43: train_loss: 0.0334, val_loss: 2.5595, val_acc: 0.5000
# Epoch 44: train_loss: 0.0311, val_loss: 2.7129, val_acc: 0.5000
# Epoch 45: train_loss: 0.0340, val_loss: 2.7482, val_acc: 0.5365
# Epoch 46: train_loss: 0.0427, val_loss: 2.7475, val_acc: 0.4948
# Epoch 47: train_loss: 0.0315, val_loss: 2.7323, val_acc: 0.4896
# Epoch 48: train_loss: 0.0320, val_loss: 2.8621, val_acc: 0.4948
# Epoch 49: train_loss: 0.0536, val_loss: 2.8788, val_acc: 0.5052
# Epoch 50: train_loss: 0.3068, val_loss: 2.3483, val_acc: 0.5312
# Epoch 51: train_loss: 0.0486, val_loss: 2.3664, val_acc: 0.5156
# Epoch 52: train_loss: 0.0416, val_loss: 2.5170, val_acc: 0.5208
# Epoch 53: train_loss: 0.0266, val_loss: 2.4866, val_acc: 0.5208
# Epoch 54: train_loss: 0.0238, val_loss: 2.6403, val_acc: 0.4948
# Epoch 55: train_loss: 0.0222, val_loss: 2.5726, val_acc: 0.5208
# Epoch 56: train_loss: 0.0172, val_loss: 2.6096, val_acc: 0.5052
# Epoch 57: train_loss: 0.0169, val_loss: 2.6005, val_acc: 0.4948
# Epoch 58: train_loss: 0.0167, val_loss: 2.6362, val_acc: 0.5156
# Epoch 59: train_loss: 0.0172, val_loss: 2.7068, val_acc: 0.5208
# Epoch 60: train_loss: 0.0161, val_loss: 2.6820, val_acc: 0.5000
# Epoch 61: train_loss: 0.0136, val_loss: 2.7794, val_acc: 0.5260
# Epoch 62: train_loss: 0.0165, val_loss: 2.7743, val_acc: 0.5260
# Epoch 63: train_loss: 0.0152, val_loss: 2.8085, val_acc: 0.5208
# Epoch 64: train_loss: 0.0145, val_loss: 2.8483, val_acc: 0.5260
# Epoch 65: train_loss: 0.0134, val_loss: 2.8426, val_acc: 0.5208
# Epoch 66: train_loss: 0.0142, val_loss: 2.8570, val_acc: 0.5156
# Epoch 67: train_loss: 0.0113, val_loss: 2.9061, val_acc: 0.5052
# Epoch 68: train_loss: 0.0139, val_loss: 2.8523, val_acc: 0.5208
# Epoch 69: train_loss: 0.0150, val_loss: 3.0479, val_acc: 0.5208
# Epoch 70: train_loss: 0.0133, val_loss: 3.0086, val_acc: 0.5156
# Epoch 71: train_loss: 0.0132, val_loss: 3.0503, val_acc: 0.5365
# Epoch 72: train_loss: 0.0148, val_loss: 3.2761, val_acc: 0.4792
# Epoch 73: train_loss: 0.0139, val_loss: 2.9903, val_acc: 0.5156
# Epoch 74: train_loss: 0.0118, val_loss: 3.0333, val_acc: 0.5208
# Epoch 75: train_loss: 0.2418, val_loss: 3.1730, val_acc: 0.4896
# Epoch 76: train_loss: 0.0367, val_loss: 2.9119, val_acc: 0.4740
# Epoch 77: train_loss: 0.0146, val_loss: 2.9511, val_acc: 0.4844
# Epoch 78: train_loss: 0.0303, val_loss: 2.9853, val_acc: 0.4844
# Epoch 79: train_loss: 0.0120, val_loss: 2.9293, val_acc: 0.5104
# Epoch 80: train_loss: 0.0106, val_loss: 2.9308, val_acc: 0.5156
# Epoch 81: train_loss: 0.0108, val_loss: 2.8532, val_acc: 0.5260
# Epoch 82: train_loss: 0.0130, val_loss: 2.9518, val_acc: 0.5208
# Epoch 83: train_loss: 0.0120, val_loss: 3.0191, val_acc: 0.5365
# Epoch 84: train_loss: 0.0109, val_loss: 2.9847, val_acc: 0.5104
# Epoch 85: train_loss: 0.0120, val_loss: 3.0319, val_acc: 0.4844
# Epoch 86: train_loss: 0.0076, val_loss: 3.0816, val_acc: 0.5052
# Epoch 87: train_loss: 0.0111, val_loss: 3.2775, val_acc: 0.5052
# Epoch 88: train_loss: 0.0107, val_loss: 3.4468, val_acc: 0.4792
# Epoch 89: train_loss: 0.0092, val_loss: 3.1479, val_acc: 0.5156
# Epoch 90: train_loss: 0.0106, val_loss: 3.1647, val_acc: 0.5156
# Epoch 91: train_loss: 0.0081, val_loss: 3.2760, val_acc: 0.4948
# Epoch 92: train_loss: 0.0101, val_loss: 3.3099, val_acc: 0.4792
# Epoch 93: train_loss: 0.0082, val_loss: 3.1867, val_acc: 0.5052
# Epoch 94: train_loss: 0.0118, val_loss: 3.1964, val_acc: 0.5312
# Epoch 95: train_loss: 0.0094, val_loss: 3.5158, val_acc: 0.4948
# Epoch 96: train_loss: 0.0157, val_loss: 3.4441, val_acc: 0.4792
# Epoch 97: train_loss: 0.0090, val_loss: 3.2966, val_acc: 0.4844
# Epoch 98: train_loss: 0.0119, val_loss: 3.2694, val_acc: 0.5104
# Epoch 99: train_loss: 0.0160, val_loss: 3.4310, val_acc: 0.4896
# Epoch 100: train_loss: 0.0068, val_loss: 3.3850, val_acc: 0.4844

# %%
def plot_accuracies(history):
    accuracies = [x['val_acc'] for x in history]
    plt.plot(accuracies, '-x')
    plt.xlabel('epoch')
    plt.ylabel('accuracy')
    plt.title('Accuracy vs. No. of epochs');

plot_accuracies(history)

# %%
def plot_losses(history):
    train_losses = [x.get('train_loss') for x in history]
    val_losses = [x['val_loss'] for x in history]
    plt.plot(train_losses, '-bx')
    plt.plot(val_losses, '-rx')
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.legend(['Training', 'Validation'])
    plt.title('Loss vs. No. of epochs');

plot_losses(history)

# %% [markdown]
# Here max accuracy provided by the first model is ~60% which is not very high. So then decided to use transfer learning method with [Resnet 50](https://fr.mathworks.com/help/deeplearning/ref/resnet50.html) to improve our accuracy.

# %% [markdown]
# ## Model 2

# %% [markdown]
# ResNet-50 is a convolutional neural network that is 50 layers deep. You can load a pretrained version of the network trained on more than a million images from the ImageNet database. The pretrained network can classify images into 1000 object categories, such as keyboard, mouse, pencil, and many animals. As a result, the network has learned rich feature representations for a wide range of images.

# %%
class ResNet(ImageClassificationBase):
    def __init__(self):
        super().__init__()
        # Use a pretrained model
        self.network = models.resnet50(pretrained=True)
        # Replace last layer
        num_ftrs = self.network.fc.in_features
        self.network.fc = nn.Linear(num_ftrs, len(dataset.classes))
    
    def forward(self, xb):
        return torch.sigmoid(self.network(xb))

model = ResNet()
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
#   0%|          | 0.00/97.8M [00:00<?, ?B/s]

# %%
to_device(model, device)
# Out:
# ResNet(
#   (network): ResNet(
#     (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer2): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (3): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer3): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (3): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (4): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (5): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer4): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#     (fc): Linear(in_features=2048, out_features=6, bias=True)
#   )
# )

# %%
evaluate(model, val_dl)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# {'val_acc': 0.1770833283662796, 'val_loss': 1.7981691360473633}

# %% [markdown]
# ### Training the model

# %%
num_epochs = 100
opt_func = torch.optim.Adam
lr = 5.5e-5

history = fit(num_epochs, lr, model, train_dl, val_dl, opt_func)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Epoch 1: train_loss: 1.3977, val_loss: 1.1923, val_acc: 0.8698
# Epoch 2: train_loss: 1.1599, val_loss: 1.1398, val_acc: 0.9271
# Epoch 3: train_loss: 1.1142, val_loss: 1.1169, val_acc: 0.9479
# Epoch 4: train_loss: 1.0827, val_loss: 1.1259, val_acc: 0.9167
# Epoch 5: train_loss: 1.0815, val_loss: 1.1127, val_acc: 0.9375
# Epoch 6: train_loss: 1.0727, val_loss: 1.0991, val_acc: 0.9635
# Epoch 7: train_loss: 1.0683, val_loss: 1.1035, val_acc: 0.9479
# Epoch 8: train_loss: 1.0569, val_loss: 1.0940, val_acc: 0.9635
# Epoch 9: train_loss: 1.0544, val_loss: 1.0892, val_acc: 0.9635
# Epoch 10: train_loss: 1.0578, val_loss: 1.0982, val_acc: 0.9479
# Epoch 11: train_loss: 1.0545, val_loss: 1.1126, val_acc: 0.9375
# Epoch 12: train_loss: 1.0552, val_loss: 1.0893, val_acc: 0.9531
# Epoch 13: train_loss: 1.0509, val_loss: 1.0847, val_acc: 0.9688
# Epoch 14: train_loss: 1.0534, val_loss: 1.1092, val_acc: 0.9219
# Epoch 15: train_loss: 1.0534, val_loss: 1.0887, val_acc: 0.9688
# Epoch 16: train_loss: 1.0511, val_loss: 1.0882, val_acc: 0.9583
# Epoch 17: train_loss: 1.0539, val_loss: 1.1005, val_acc: 0.9375
# Epoch 18: train_loss: 1.0519, val_loss: 1.0908, val_acc: 0.9583
# Epoch 19: train_loss: 1.0530, val_loss: 1.0870, val_acc: 0.9635
# Epoch 20: train_loss: 1.0525, val_loss: 1.1089, val_acc: 0.9427
# Epoch 21: train_loss: 1.0518, val_loss: 1.0905, val_acc: 0.9427
# Epoch 22: train_loss: 1.0560, val_loss: 1.1055, val_acc: 0.9375
# Epoch 23: train_loss: 1.0613, val_loss: 1.0919, val_acc: 0.9375
# Epoch 24: train_loss: 1.0539, val_loss: 1.1040, val_acc: 0.9323
# Epoch 25: train_loss: 1.0532, val_loss: 1.1214, val_acc: 0.9323
# Epoch 26: train_loss: 1.0507, val_loss: 1.0917, val_acc: 0.9375
# Epoch 27: train_loss: 1.0483, val_loss: 1.0945, val_acc: 0.9479
# Epoch 28: train_loss: 1.0517, val_loss: 1.0891, val_acc: 0.9531
# Epoch 29: train_loss: 1.0493, val_loss: 1.0786, val_acc: 0.9583
# Epoch 30: train_loss: 1.0478, val_loss: 1.0956, val_acc: 0.9531
# Epoch 31: train_loss: 1.0477, val_loss: 1.0974, val_acc: 0.9583
# Epoch 32: train_loss: 1.0511, val_loss: 1.1047, val_acc: 0.9427
# Epoch 33: train_loss: 1.0534, val_loss: 1.0891, val_acc: 0.9531
# Epoch 34: train_loss: 1.0522, val_loss: 1.0916, val_acc: 0.9583
# Epoch 35: train_loss: 1.0500, val_loss: 1.0921, val_acc: 0.9531
# Epoch 36: train_loss: 1.0472, val_loss: 1.0738, val_acc: 0.9792
# Epoch 37: train_loss: 1.0524, val_loss: 1.0797, val_acc: 0.9635
# Epoch 38: train_loss: 1.0487, val_loss: 1.1058, val_acc: 0.9375
# Epoch 39: train_loss: 1.0468, val_loss: 1.0935, val_acc: 0.9427
# Epoch 40: train_loss: 1.0504, val_loss: 1.0802, val_acc: 0.9635
# Epoch 41: train_loss: 1.0517, val_loss: 1.1031, val_acc: 0.9479
# Epoch 42: train_loss: 1.0506, val_loss: 1.0862, val_acc: 0.9479
# Epoch 43: train_loss: 1.0500, val_loss: 1.0823, val_acc: 0.9635
# Epoch 44: train_loss: 1.0473, val_loss: 1.0849, val_acc: 0.9583
# Epoch 45: train_loss: 1.0470, val_loss: 1.0879, val_acc: 0.9583
# Epoch 46: train_loss: 1.0464, val_loss: 1.0916, val_acc: 0.9479
# Epoch 47: train_loss: 1.0466, val_loss: 1.0879, val_acc: 0.9531
# Epoch 48: train_loss: 1.0451, val_loss: 1.0866, val_acc: 0.9635
# Epoch 49: train_loss: 1.0447, val_loss: 1.0945, val_acc: 0.9531
# Epoch 50: train_loss: 1.0448, val_loss: 1.0891, val_acc: 0.9479
# Epoch 51: train_loss: 1.0517, val_loss: 1.1795, val_acc: 0.8490
# Epoch 52: train_loss: 1.0604, val_loss: 1.1304, val_acc: 0.9115
# Epoch 53: train_loss: 1.0524, val_loss: 1.1032, val_acc: 0.9375
# Epoch 54: train_loss: 1.0478, val_loss: 1.0898, val_acc: 0.9635
# Epoch 55: train_loss: 1.0475, val_loss: 1.0995, val_acc: 0.9479
# Epoch 56: train_loss: 1.0452, val_loss: 1.0840, val_acc: 0.9635
# Epoch 57: train_loss: 1.0466, val_loss: 1.1076, val_acc: 0.9323
# Epoch 58: train_loss: 1.0449, val_loss: 1.0946, val_acc: 0.9531
# Epoch 59: train_loss: 1.0447, val_loss: 1.0916, val_acc: 0.9531
# Epoch 60: train_loss: 1.0445, val_loss: 1.0799, val_acc: 0.9635
# Epoch 61: train_loss: 1.0449, val_loss: 1.0788, val_acc: 0.9740
# Epoch 62: train_loss: 1.0452, val_loss: 1.0794, val_acc: 0.9688
# Epoch 63: train_loss: 1.0449, val_loss: 1.0854, val_acc: 0.9635
# Epoch 64: train_loss: 1.0449, val_loss: 1.0894, val_acc: 0.9531
# Epoch 65: train_loss: 1.0556, val_loss: 1.1280, val_acc: 0.9115
# Epoch 66: train_loss: 1.0523, val_loss: 1.1115, val_acc: 0.9323
# Epoch 67: train_loss: 1.0536, val_loss: 1.1195, val_acc: 0.9115
# Epoch 68: train_loss: 1.0502, val_loss: 1.1098, val_acc: 0.9271
# Epoch 69: train_loss: 1.0473, val_loss: 1.1023, val_acc: 0.9375
# Epoch 70: train_loss: 1.0473, val_loss: 1.1167, val_acc: 0.9219
# Epoch 71: train_loss: 1.0455, val_loss: 1.0853, val_acc: 0.9583
# Epoch 72: train_loss: 1.0459, val_loss: 1.0932, val_acc: 0.9531
# Epoch 73: train_loss: 1.0479, val_loss: 1.0884, val_acc: 0.9583
# Epoch 74: train_loss: 1.0466, val_loss: 1.0906, val_acc: 0.9583
# Epoch 75: train_loss: 1.0456, val_loss: 1.0868, val_acc: 0.9635
# Epoch 76: train_loss: 1.0460, val_loss: 1.1042, val_acc: 0.9427
# Epoch 77: train_loss: 1.0451, val_loss: 1.1089, val_acc: 0.9427
# Epoch 78: train_loss: 1.0445, val_loss: 1.1046, val_acc: 0.9479
# Epoch 79: train_loss: 1.0450, val_loss: 1.0983, val_acc: 0.9427
# Epoch 80: train_loss: 1.0445, val_loss: 1.0964, val_acc: 0.9583
# Epoch 81: train_loss: 1.0451, val_loss: 1.0884, val_acc: 0.9635
# Epoch 82: train_loss: 1.0446, val_loss: 1.0900, val_acc: 0.9583
# Epoch 83: train_loss: 1.0443, val_loss: 1.0876, val_acc: 0.9531
# Epoch 84: train_loss: 1.0445, val_loss: 1.0793, val_acc: 0.9688
# Epoch 85: train_loss: 1.0453, val_loss: 1.0797, val_acc: 0.9688
# Epoch 86: train_loss: 1.0485, val_loss: 1.1034, val_acc: 0.9531
# Epoch 87: train_loss: 1.0496, val_loss: 1.1419, val_acc: 0.8958
# Epoch 88: train_loss: 1.0591, val_loss: 1.1569, val_acc: 0.8906
# Epoch 89: train_loss: 1.0553, val_loss: 1.1378, val_acc: 0.9010
# Epoch 90: train_loss: 1.0467, val_loss: 1.1050, val_acc: 0.9427
# Epoch 91: train_loss: 1.0453, val_loss: 1.1025, val_acc: 0.9427
# Epoch 92: train_loss: 1.0485, val_loss: 1.1151, val_acc: 0.9167
# Epoch 93: train_loss: 1.0453, val_loss: 1.1029, val_acc: 0.9427
# Epoch 94: train_loss: 1.0461, val_loss: 1.1096, val_acc: 0.9271
# Epoch 95: train_loss: 1.0455, val_loss: 1.1010, val_acc: 0.9375
# Epoch 96: train_loss: 1.0456, val_loss: 1.1080, val_acc: 0.9375
# Epoch 97: train_loss: 1.0447, val_loss: 1.0996, val_acc: 0.9479
# Epoch 98: train_loss: 1.0447, val_loss: 1.0997, val_acc: 0.9531
# Epoch 99: train_loss: 1.0444, val_loss: 1.1010, val_acc: 0.9427
# Epoch 100: train_loss: 1.0443, val_loss: 1.0967, val_acc: 0.9479

# %%
def plot_accuracies(history):
    accuracies = [x['val_acc'] for x in history]
    plt.plot(accuracies, '-x')
    plt.xlabel('epoch')
    plt.ylabel('accuracy')
    plt.title('Accuracy vs. No. of epochs');

plot_accuracies(history)

# %%
def plot_losses(history):
    train_losses = [x.get('train_loss') for x in history]
    val_losses = [x['val_loss'] for x in history]
    plt.plot(train_losses, '-bx')
    plt.plot(val_losses, '-rx')
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.legend(['Training', 'Validation'])
    plt.title('Loss vs. No. of epochs');

plot_losses(history)

# %% [markdown]
# Using Resnet50 has dramaticaly increased our accuracy score up to 96% on the validation dataset.

# %% [markdown]
# For web app, need to save here the weights of trained model. Eventually will load later those weights within app.py script.

# %%
torch.save({"state_dict": model.state_dict()}, "/gdrive/MyDrive/waste_model/pre-trained_CNN.pth")

# %% [markdown]
# ### Accuracy on test dataset

# %%
test_dl = DataLoader(test_ds, batch_size, shuffle = True, num_workers = 4, pin_memory = True)
test_dl = DeviceDataLoader(test_dl, device)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %%
correct = 0
total = 0
with torch.no_grad():
    for data in test_dl:
        images, labels = data
        #print(labels)
    
        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
        #if (predicted == labels):
            #class_correct[data] += 1
    
     
print('Accuracy of the network on the test images: %d %%' % (
    100 * correct / total))
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Accuracy of the network on the test images: 92 %

# %%
class_correct = list(0. for i in range(6))
class_total = list(0. for i in range(6))
with torch.no_grad():
    for data in test_dl:
        images, labels = data
        outputs = model(images)
        _, predicted = torch.max(outputs, 1)
        c = (predicted == labels).squeeze()
        
        
        for i in range(3):
            label = labels[i]
            class_correct[label] += c[i].item()
            class_total[label] += 1


for i in range(6):
    print('Accuracy of %5s : %2d %%' % (
        classes[i], 100 * class_correct[i] / class_total[i]))
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Accuracy of metal : 90 %
# Accuracy of plastic : 96 %
# Accuracy of cardboard : 96 %
# Accuracy of paper : 96 %
# Accuracy of trash : 90 %
# Accuracy of glass : 87 %

# %% [markdown]
# It is evident that the model performs very well on cardboard, paper, and plastic images but not on glass. Some ideas for solving it :
#
# *   Incease epoch for training but keep carefull about overfitting
# *   Data augmentation
# *   Change size of input image
# *   ...

# %% [markdown]
# ### Visualization Prediction

# %%
def predict_image(img, model):
    # Convert to a batch of 1
    xb = to_device(img.unsqueeze(0), device)
    # Get predictions from model
    yb = model(xb)
    # Pick index with highest probability
    prob, preds  = torch.max(yb, dim=1)
    # Retrieve the class label
    return dataset.classes[preds[0].item()]

# %%
img, label = test_ds[17]
plt.imshow(img.permute(1, 2, 0))
print('Label:', dataset.classes[label], ', Predicted:', predict_image(img, model))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Label: metal , Predicted: metal

# %%
img, label = test_ds[23]
plt.imshow(img.permute(1, 2, 0))
print('Label:', dataset.classes[label], ', Predicted:', predict_image(img, model))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Label: glass , Predicted: glass

# %%
img, label = test_ds[1]
plt.imshow(img.permute(1, 2, 0))
print('Label:', dataset.classes[label], ', Predicted:', predict_image(img, model))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Label: plastic , Predicted: plastic

# %% [markdown]
# ### Predicting External Images:

# %%
import urllib.request

urllib.request.urlretrieve("https://cdn.mos.cms.futurecdn.net/WTXCtPFr6P7EygfJZ8DsA3-1200-80.jpg", "plastic.jpg")

urllib.request.urlretrieve("https://external-content.duckduckgo.com/iu/?u=http%3A%2F%2Fi.ebayimg.com%2Fimages%2Fi%2F291536274730-0-1%2Fs-l1000.jpg&f=1&nofb=1", "cardboard.jpg")    

urllib.request.urlretrieve("https://external-content.duckduckgo.com/iu/?u=https%3A%2F%2Ftse4.mm.bing.net%2Fth%3Fid%3DOIP.2F0uH6BguQMctAYEJ-s-1gHaHb%26pid%3DApi&f=1", "cans.jpg") 

urllib.request.urlretrieve("https://external-content.duckduckgo.com/iu/?u=https%3A%2F%2Ftinytrashcan.com%2Fwp-content%2Fuploads%2F2018%2F08%2Ftiny-trash-can-bulk-wine-bottle.jpg&f=1&nofb=1", "wine-trash.jpg")

urllib.request.urlretrieve("https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSvMq713Mvx_MwUYrMuU2QMk8FEl9m_aP-qLw&usqp=CAU", "paper-trash.jpg")

urllib.request.urlretrieve("https://programmingaltanai.files.wordpress.com/2020/09/1.jpg?w=616", "mixed-trash.jpg")
# Out:
# ('mixed-trash.jpg', <http.client.HTTPMessage at 0x7f54c4069790>)

# %%
loaded_model = model

# %%
from PIL import Image
from pathlib import Path

def predict_external_image(image_name):
    image = Image.open(Path('./' + image_name))

    example_image = transformations(image)
    plt.imshow(example_image.permute(1, 2, 0))
    print("The image resembles", predict_image(example_image, loaded_model) + ".")

# %%
predict_external_image('plastic.jpg')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# The image resembles plastic.

# %%
predict_external_image('cans.jpg')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# The image resembles metal.

# %%
predict_external_image('wine-trash.jpg')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# The image resembles cardboard.

# %%
predict_external_image('paper-trash.jpg')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# The image resembles metal.

# %%
predict_external_image('plastic.jpg')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# The image resembles plastic.

# %%
predict_external_image('mixed-trash.jpg')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# The image resembles cardboard.
